# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
x=np.random.rand(50)
y=np.random.rand(50)

# %%
plt.scatter(x,y)
plt.show()

# %%
plt.show()

# %%
df= pd.read_csv("http://bit.ly//drinksbycountry")
df.head()
# Out:
#        country  beer_servings  spirit_servings  wine_servings  \
# 0  Afghanistan              0                0              0
# 1      Albania             89              132             54
# 2      Algeria             25                0             14
# 3      Andorra            245              138            312
# 4       Angola            217               57             45
#
#    total_litres_of_pure_alcohol continent
# 0                           0.0      Asia
# 1                           4.9    Europe
# 2                           0.7    Africa
# 3                          12.4    Europe
# 4                           5.9    Africa

# %%
x=df['beer_servings'].head()
y=df['country'].head()
z=df['wine_servings'].head()
#plt.scatter(x,y,z)
plt.plot(x,z)
plt.xlabel('beer_servings')
plt.ylabel('country')
plt.grid()
plt.legend()
plt.show()

# %%
y=df['beer_servings']
x=df['country']
z=df['wine_servings'].head(50)
plt.scatter(x,y)
plt.xlabel('beer_servings')
plt.ylabel('country')
plt.grid()
plt.legend()
plt.show()

# %%
plt.hist(y,normed=1)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\axes\_axes.py:6571: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "
# (array([0.00992173, 0.00330724, 0.00316944, 0.00206703, 0.00137802,
#         0.00234263, 0.00206703, 0.00110241, 0.00041341, 0.00082681]),
#  array([  0. ,  37.6,  75.2, 112.8, 150.4, 188. , 225.6, 263.2, 300.8,
#         338.4, 376. ]),
#  <a list of 10 Patch objects>)

# %%
x = np.arange(0,5,0.1)
y = np.tan(x)
plt.subplot(2,2,2)
plt.scatter(x,y,label='line 1')
plt.subplot(2,3,4)
plt.scatter([1,2,3,4,5],[2,3,4,5,5],label = 'line2')
plt.xlabel("x")
plt.ylabel("y")
plt.legend()

plt.show()
